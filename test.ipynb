# %%
import pandas
import numpy
from matplotlib import pyplot
from marketing_data_cleaning import PROJECT_PATH

# %%
path = PROJECT_PATH.joinpath('harden.csv')

# %%
df = pandas.read_csv(path)

# %%
fig, ax1 = pyplot.subplots(figsize=[15, 6])

ax1.set_xlabel('Games')
ax1.set_ylabel('Points', color='b')
ax1.plot(df['YEAR'], df['PTS'], label='Points', color='b', marker='o')
ax1.tick_params(axis='y', labelcolor='b')

for i, item in enumerate(df.itertuples()):
    ax1.annotate(item.FGPCT, (df.loc[item.Index, 'YEAR'], df.loc[item.Index, 'FGPCT']),
                 textcoords="offset points", xytext=(0, 5), ha='center')

ax2 = ax1.twinx()

ax2.set_ylabel('Field Goal %', color='g')
ax2.plot(df['YEAR'], df['FGPCT'], label='Field Goal %', color='g', marker='s')
ax2.tick_params(axis='y', labelcolor='g')

ax1.tick_params(axis='x', rotation=45)
ax1.set_xticks(df['YEAR'])

lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left', bbox_to_anchor=(0.7, 1))

pyplot.title('Performance')

pyplot.show()
